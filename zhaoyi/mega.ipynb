# %%
import dendropy

import phylo

# %%
pseudo_tree = dendropy.Tree.get(path='../../zhaoyi/mega/pseudo/pseudo_ml.nwk', schema='newick')

print(pseudo_tree.as_ascii_plot())
# Out:
#                                                           /--- 5920
#                                                       /---+
#                                                    /--+   \--- CPHL950
#                                                    |  |
#                              /---------------------+  \------- Mi159
#                              |                     |
#                              |                     |      /--- IC1
#                              |                     \------+
#                              |                            \--- SWPA15J NSWPA15a
#                              |
#                              |                            /--- Lw1047
#                              |                        /---+
#                              |                     /--+   \--- CPHL2000
#                              |                     |  |
#                              |      /--------------+  \------- JD318
# ...

# %%
phylo.draw_tree('../../zhaoyi/mega/pseudo/pseudo_ml.nwk', '$Pseudomonas$ maximum likelihood phylogenetic tree')

# %%
phylo.draw_tree('../../zhaoyi/mega/staph/staph_ml.nwk', '$Staphylococcus$ maximum likelihood phylogenetic tree')
