# %%
import numpy as np
import pandas as pd

from load import load_pseudo

pd.options.display.precision = 3
pd.options.display.max_colwidth = 12

# %matplotlib inline

# %%
records = load_pseudo(True)
mask = (records['toby'].notna() & records['carb'].notna())
records.head()
# Out:
#       id     sequence  missing  missing_%   sequence_i  missing_i  \
# 0  TA151  ATGAGTGA...    31842      6.588  ATGAGTGA...      28410
# 1    IC1  ATGAGTGA...    46071      9.532  ATGAGTGA...      34714
# 2   A237  ATGAGTGA...    44514      9.210  ATGAGTGA...      35933
# 3   5920  ATGAGTGA...    49497     10.241  ATGAGTGA...      36873
# 4  LiA96  ATGAGTGA...    44067      9.117  ATGAGTGA...      34454
#
#    missing_%_i   carb   toby  carb_num  toby_num
# 0        5.878   True  False      -2.0      16.0
# 1        7.182  False  False       2.0      14.0
# 2        7.434   True  False      -1.0       4.0
# 3        7.629    NaN    NaN       NaN       NaN
# 4        7.128  False  False       0.0      18.0

# %%
import os

random_state = 42

s = {'{}_{}_{}_{}.npy'.format(impute, nc, selection, extraction)
     for impute in 'io'
     for nc in 'nc'
     for selection in '-vx'
     for extraction in '-pts'}

# numerical data
data_u = {d: np.load(os.path.join('../data/pseudo/preprocess', d)) for d in s}
for k, v in data_u.items():
    if v.shape[0] != 119:
        print(k)

# one-hot encoded data
data_e = {d: np.load(os.path.join('../data/pseudo/preprocess/onehot', d)) for d in s}

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Classification

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# silence warning for getting 0 on f1 score
from sklearn.exceptions import UndefinedMetricWarning
import warnings
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)

# %%
y_c = records['carb'][mask].astype('?')
metrics_c = [accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score]

# %%
def train_clfs(clf, model, encode):
    results = []
    data = data_e if encode else data_u
    for d, X in data.items():
        X_train, X_test, y_train, y_test = train_test_split(X, y_c, random_state=random_state,
                                                            stratify=y_c, train_size=0.7)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        m = {metric.__name__.replace('_score', ''): metric(y_test, y_pred)
             for metric in metrics_c}
        m.update({'file': d, 'encode': encode, 'model': model})
        results.append(m)
    return results

# %% [markdown]
# ### Logistic regression

# %%
# 3 to 5 minutes in total
lr = LogisticRegression(penalty='none', class_weight='balanced',
                         solver='lbfgs', max_iter=2000, n_jobs=5, warm_start=False)
# %time lr_u = train_clfs(lr, 'logistic', False)
# %time lr_e = train_clfs(lr, 'logistic', True)
# Out:
# CPU times: user 1min 29s, sys: 6.7 s, total: 1min 36s
# Wall time: 1min 41s
# CPU times: user 4min 9s, sys: 14.3 s, total: 4min 23s
# Wall time: 2min 26s

# %% [markdown]
# ###  Random forest

# %%
# 45*2 seconds
rfc = RandomForestClassifier(n_estimators=500, n_jobs=5, class_weight='balanced')
# %time rfc_u = train_clfs(rfc, 'rf', False)
# %time rfc_e = train_clfs(rfc, 'rf', True)
# Out:
# CPU times: user 1min 2s, sys: 8.71 s, total: 1min 11s
# Wall time: 47.4 s
# CPU times: user 1min 8s, sys: 8.4 s, total: 1min 17s
# Wall time: 47 s

# %% [markdown]
# ###  Support vector machine

# %%
# 1 and 2 minutes
svc = SVC(gamma='auto', class_weight='balanced')
# %time svc_u = train_clfs(svc, 'svm', False)
# %time svc_e = train_clfs(svc, 'svm', True)
# Out:
# CPU times: user 49.3 s, sys: 2.2 s, total: 51.5 s
# Wall time: 51.7 s
# CPU times: user 1min 41s, sys: 2.42 s, total: 1min 44s
# Wall time: 1min 44s

# %% [markdown]
# ### Results

# %%
results_c = pd.DataFrame(lr_e + lr_u + rfc_u + rfc_e + svc_u + svc_e)
results_c.to_csv('result/result_pseudo_clf.csv', index=False)
results_c.head()
# Out:
#    accuracy  balanced_accuracy  precision  recall     f1         file  encode  \
# 0     0.778        0.500            0.000   0.000  0.000  i_c_v_t.npy    True
# 1     0.778        0.500            0.000   0.000  0.000  o_c_x_p.npy    True
# 2     0.778        0.500            0.000   0.000  0.000  o_n_x_t.npy    True
# 3     0.750        0.705            0.455   0.625  0.526  o_n_v_-.npy    True
# 4     0.778        0.500            0.000   0.000  0.000  i_c_-_s.npy    True
#
#       model
# 0  logistic
# 1  logistic
# 2  logistic
# 3  logistic
# 4  logistic

# %%
results_c.sort_values(by=['f1'], ascending=False)
# Out:
#      accuracy  balanced_accuracy  precision  recall     f1         file  \
# 195     0.889        0.884            0.700   0.875  0.778  o_n_v_-.npy
# 89      0.889        0.839            0.750   0.750  0.750  o_n_x_-.npy
# 254     0.861        0.866            0.636   0.875  0.737  o_c_-_-.npy
# 41      0.861        0.821            0.667   0.750  0.706  o_n_x_-.npy
# 281     0.861        0.821            0.667   0.750  0.706  o_n_x_-.npy
# ..        ...          ...              ...     ...    ...          ...
# 149     0.778        0.500            0.000   0.000  0.000  o_n_-_t.npy
# 150     0.778        0.500            0.000   0.000  0.000  o_n_x_p.npy
# 151     0.778        0.500            0.000   0.000  0.000  o_c_-_p.npy
# 152     0.778        0.500            0.000   0.000  0.000  o_n_v_s.npy
# 144     0.778        0.500            0.000   0.000  0.000  i_c_v_t.npy
#
#      encode     model
# 195   False       svm
# 89    False  logistic
# 254    True       svm
# 41     True  logistic
# 281    True       svm
# ..      ...       ...
# 149    True        rf
# 150    True        rf
# 151    True        rf
# 152    True        rf
# 144    True        rf
#
# [288 rows x 8 columns]

# %% [markdown]
# # Regression

# %%
from sklearn.metrics import r2_score, max_error, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
y_r = records['carb_num'][mask]
metrics_r = [r2_score, max_error, mean_absolute_error, mean_squared_error]

# %%
def train_regs(reg, model, encode):
    results = []
    data = data_e if encode else data_u
    for d, X in data.items():
        X_train, X_test, y_train, y_test = train_test_split(X, y_r, random_state=random_state,
                                                            train_size=0.7)
        reg.fit(X_train, y_train)
        y_pred = reg.predict(X_test)
        m = {metric.__name__.replace('_score', ''): metric(y_test, y_pred)
             for metric in metrics_r}
        m.update({'file': d, 'encode': encode, 'model': model})
        results.append(m)
    return results

# %% [markdown]
# ### Linear regression

# %%
# 20*2 seconds
lrr = LinearRegression(n_jobs=5)
# %time lrr_u = train_regs(lrr, 'linear', False)
# %time lrr_e = train_regs(lrr, 'linear', True)
# Out:
# CPU times: user 4min 51s, sys: 13.3 s, total: 5min 4s
# Wall time: 15.9 s
# CPU times: user 8min 53s, sys: 25.6 s, total: 9min 19s
# Wall time: 21.9 s

# %% [markdown]
# ### Random forest

# %%
# 20 and 50 minutes
rfr = RandomForestRegressor(n_estimators=500, n_jobs=5)
# %time rfr_u = train_regs(rfr, 'rf', False)
# %time rfr_e = train_regs(rfr, 'rf', True)
# Out:
# CPU times: user 1h 30min 13s, sys: 28 s, total: 1h 30min 41s
# Wall time: 18min 38s
# CPU times: user 3h 57min, sys: 56.4 s, total: 3h 57min 56s
# Wall time: 48min 11s

# %% [markdown]
# ### Support vector machine

# %%
# 1 and 1.5 minutes
svr = SVR(gamma='auto')
# %time svr_u = train_regs(svr, 'svm', False)
# %time svr_e = train_regs(svr, 'svm', True)
# Out:
# CPU times: user 48.2 s, sys: 3.18 s, total: 51.4 s
# Wall time: 51.5 s
# CPU times: user 1min 24s, sys: 3.68 s, total: 1min 28s
# Wall time: 1min 28s

# %%
results_r = pd.DataFrame(lrr_e + lrr_u + rfr_u + rfr_e + svr_u + svr_e)
results_r.to_csv('result/result_pseudo_reg.csv', index=False)
results_r.head()
# Out:
#       r2  max_error  mean_absolute_error  mean_squared_error         file  \
# 0 -4.610     64.827       18.871              628.008         i_c_v_t.npy
# 1 -0.003     34.173        8.021              112.330         o_c_x_p.npy
# 2 -0.096     35.593        8.754              122.673         o_n_x_t.npy
# 3 -0.135     32.478        8.937              127.029         o_n_v_-.npy
# 4  0.014     32.913        7.861              110.353         i_c_-_s.npy
#
#    encode   model
# 0    True  linear
# 1    True  linear
# 2    True  linear
# 3    True  linear
# 4    True  linear

# %%
results_r.sort_values(by=['mean_squared_error'])
# Out:
#          r2  max_error  mean_absolute_error  mean_squared_error         file  \
# 134   0.079     32.932        7.994              103.135         o_c_v_p.npy
# 136   0.027     29.160        7.833              108.943         i_n_x_t.npy
# 129   0.021     24.740        7.780              109.563         o_c_x_s.npy
# 33    0.020     33.059        7.873              109.688         o_c_x_s.npy
# 35    0.020     32.705        7.846              109.722         i_n_x_s.npy
# ..      ...        ...          ...                  ...                 ...
# 71  -20.476    195.814       33.036             2404.067         i_n_v_s.npy
# 83  -25.124    150.952       39.258             2924.399         i_n_x_s.npy
# 78  -41.163    165.162       56.333             4719.836         i_c_v_s.npy
# 67  -52.805    225.895       55.153             6022.988         i_c_x_s.npy
# 52  -68.246    211.497       71.462             7751.516         i_c_-_s.npy
#
#      encode   model
# 134   False      rf
# 136   False      rf
# 129   False      rf
# 33     True  linear
# 35     True  linear
# ..      ...     ...
# 71    False  linear
# 83    False  linear
# 78    False  linear
# 67    False  linear
# 52    False  linear
#
# [288 rows x 7 columns]
